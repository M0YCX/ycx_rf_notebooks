# %% [markdown]
# # 2SC2498 - Feedback Amplifier
#
# > Refs:
# > * file:///home/bev/Documents/Radio/DataSheets/BJTs/2SC2498.pdf  (Toshiba)

# %%
import os
import sys

sys.path.append("../../../lib")
from feedback import complex_fba

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# 2SC2498 - file:///home/bev/Documents/Radio/DataSheets/BJTs/2SC2498.pdf
eL = 1.75
eC = 0.2
n = complex_fba(
    title="2SC2498 Bias:${Ie_mA}mA, F:${F_mhz}MHz",
    F_mhz=500,  # 25,
    FT_mhz=3500,
    B0=80,
    Ie_mA=10,
    Rbp=1.0,
    Re=0,
    extLe_nH=eL,
    extLb_nH=eL,
    extLc_nH=eL,
    extCin_pF=eC,
    extCout_pF=eC,
    extCrev_pF=eC,
    Ccb_pF=0.95,
    Cce_pF=0.2,
    Cf_pF=100000,
    Lf_nH=0,
    Rf=51000,
    ZS_real=50,
    ZS_imag=0,
    ZL_real=50,
    ZL_imag=0,
    N=1,
    from_mhz=50,
    to_mhz=1000,
)

n.write_touchstone(
    "2SC2498_CE_Ie10mA_nbgen",
    dir=f"{os.environ['HOME']}/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# Out:
# <h1>2SC2498 Bias:10mA, F:500MHz</h1>

# %%
# 2SC2498 - file:///home/bev/Documents/Radio/DataSheets/BJTs/2SC2498.pdf
eL = 1.75
eC = 0.2
n = complex_fba(
    title="2SC2498 Bias:${Ie_mA}mA, F:${F_mhz}MHz",
    F_mhz=70,
    FT_mhz=3500,
    B0=80,
    Ie_mA=4,
    Rbp=1.0,
    Re=0,
    extLe_nH=eL,
    extLb_nH=eL,
    extLc_nH=eL,
    extCin_pF=eC,
    extCout_pF=eC,
    extCrev_pF=eC,
    Ccb_pF=0.95,
    Cce_pF=0.2,
    Cf_pF=100000,
    Lf_nH=10,
    Rf=51000,
    ZS_real=50,
    ZS_imag=0,
    ZL_real=50,
    ZL_imag=0,
    N=1,
    from_mhz=10,
    to_mhz=1000,
)

n.write_touchstone(
    "2SC2498_CE_Ie4mA_nbgen",
    dir=f"{os.environ['HOME']}/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# Out:
# <h1>2SC2498 Bias:4mA, F:70MHz</h1>

# %%
# 2SC2498 - file:///home/bev/Documents/Radio/DataSheets/BJTs/2SC2498.pdf
eL = 1.75
eC = 0.2
n = complex_fba(
    title="2SC2498 Bias:${Ie_mA}mA, F:${F_mhz}MHz, with feedback, stable ok down to 4MHz",
    F_mhz=70,
    FT_mhz=3500,
    B0=185,
    Ie_mA=4,
    Rbp=1.0,
    Re=0,
    extLe_nH=eL,
    extLb_nH=eL,
    extLc_nH=eL,
    extCin_pF=eC,
    extCout_pF=eC,
    extCrev_pF=eC,
    Ccb_pF=0.95,
    Cce_pF=0.2,
    Cf_pF=330,
    Lf_nH=10,
    Rf=430,
    ZS_real=50,
    ZS_imag=0,
    ZL_real=50,
    ZL_imag=0,
    N=1,
    from_mhz=1,
    to_mhz=1000,
)

n.write_touchstone(
    "2SC2498_CE_Ie4mA_with_feedback_nbgen",
    dir=f"{os.environ['HOME']}/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# Out:
# <h1>2SC2498 Bias:4mA, F:70MHz, with feedback, stable ok down to 4MHz</h1>

# %%
# 2SC2498 - file:///home/bev/Documents/Radio/DataSheets/BJTs/2SC2498.pdf
eL = 1.75
eC = 0.2
n = complex_fba(
    title="2SC2498 Bias:${Ie_mA}mA, F:${F_mhz}MHz, with feedback, stable ok down to 1MHz",
    F_mhz=70,
    FT_mhz=3500,
    B0=185,
    Ie_mA=4,
    Rbp=1.0,
    Re=0,
    extLe_nH=eL,
    extLb_nH=eL,
    extLc_nH=eL,
    extCin_pF=eC,
    extCout_pF=eC,
    extCrev_pF=eC,
    Ccb_pF=0.95,
    Cce_pF=0.2,
    Cf_pF=1300,
    Lf_nH=10,
    Rf=430,
    ZS_real=50,
    ZS_imag=0,
    ZL_real=50,
    ZL_imag=0,
    N=1,
    from_mhz=1,
    to_mhz=1000,
)

n.write_touchstone(
    "2SC2498_CE_Ie4mA_with_feedback_stab1mhz_nbgen",
    dir=f"{os.environ['HOME']}/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# Out:
# <h1>2SC2498 Bias:4mA, F:70MHz, with feedback, stable ok down to 1MHz</h1>
