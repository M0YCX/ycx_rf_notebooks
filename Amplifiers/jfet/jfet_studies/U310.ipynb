# %% [markdown]
# # U310

# %%
import sys

sys.path.append("../../../lib")
from models import calc_plot_jfet, interactive_calc_plot_jfet

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# U310 Common Gate - Close match to book: Designing With Field Effect Transistors Figure 4-6 Page 150.
calc_plot_jfet(
    title="U310 Common Gate",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=0.1,
    L2_nH=0.1,
    L3_nH=0.1,
    R1=4,
    R2=1,
    R3=1,
    Idss_mA=30,
    VgsOff=-3.91,
    config="cg",
    # Vgs=-1.65,  # -0.7,
    ID=10 * 10**-3,
    Ffrom=100 * 10**6,
)
# Out:
# beta=1.962311 mS
# gm=8.859595 mS
# 2-Port Network: '',  100000000.0-1000000000.0 Hz, 100 pts, z0=[50.+0.j 50.+0.j]

# %%
# U310 Common Source - Close match to book: Designing With Field Effect Transistors Figure 4-6 Page 150.
calc_plot_jfet(
    title="U310 Common Source",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=0.1,
    L2_nH=0.1,
    L3_nH=0.1,
    R1=4,
    R2=1,
    R3=1,
    Idss_mA=30,
    VgsOff=-3.91,
    config="cs",
    # Vgs=-0.7,
    ID=10 * 10**-3,
    Ffrom=100 * 10**6,
)
# Out:
# beta=1.962311 mS
# gm=8.859595 mS
# 2-Port Network: '',  100000000.0-1000000000.0 Hz, 100 pts, z0=[50.+0.j 50.+0.j]
