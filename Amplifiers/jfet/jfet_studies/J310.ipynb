# %% [markdown]
# # J310

# %%
import sys

sys.path.append("../../../lib")
from models import calc_plot_jfet, interactive_calc_plot_jfet

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# J310 - Close match to Fairchild datasheet
n = calc_plot_jfet(
    title="J310 Common Gate VDG:12V",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=1.7,
    L2_nH=1.1,
    L3_nH=1.1,
    R1=4,
    R2=1,
    R3=4,
    Idss_mA=30,
    VgsOff=-3.91,
    config="cg",
    # Vgs=-0.7,
    ID=10 * 10**-3,
    Ffrom=10 * 10**6,
)

n.write_touchstone(
    "J310_CG_12V_ID10mA_nbgen",
    dir="/home/bev/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# print(n.write_touchstone("n", dir="/tmp", return_string=True))
# Out:
# beta=1.962311 mS
# gm=8.859595 mS

# %%
# J310 - Close match to Fairchild datasheet
n = calc_plot_jfet(
    title="J310 Common Source VDS:12V",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=1.7,
    L2_nH=1.1,
    L3_nH=1.1,
    R1=4,
    R2=1,
    R3=4,
    Idss_mA=30,
    VgsOff=-3.91,
    config="cs",
    # Vgs=-0.7,
    ID=10 * 10**-3,
    Ffrom=10 * 10**6,
)

n.write_touchstone(
    "J310_CS_12V_ID10mA_nbgen",
    dir="/home/bev/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# print(n.write_touchstone("n", dir="/tmp", return_string=True))
# Out:
# beta=1.962311 mS
# gm=8.859595 mS

# %%
# J310 - Close match to Fairchild datasheet
n = calc_plot_jfet(
    title="J310 Common Gate VDG:9V",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=1.7,
    L2_nH=1.1,
    L3_nH=1.1,
    R1=4,
    R2=1,
    R3=4,
    Idss_mA=30,
    VgsOff=-3.86,
    config="cg",
    # Vgs=-0.7,
    ID=10 * 10**-3,
    Ffrom=10 * 10**6,
)

n.write_touchstone(
    "J310_CG_9V_ID10mA_nbgen",
    dir="/home/bev/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# print(n.write_touchstone("n", dir="/tmp", return_string=True))
# Out:
# beta=2.013477 mS
# gm=8.974357 mS

# %%
# J310 - Close match to Fairchild datasheet
n = calc_plot_jfet(
    title="J310 Common Source VDS:9V",
    Cdg_pf=2.5,
    Cgs_pf=3.0,
    Cds_pf=0.1,
    L1_nH=1.7,
    L2_nH=1.1,
    L3_nH=1.1,
    R1=4,
    R2=1,
    R3=4,
    Idss_mA=30,
    VgsOff=-3.86,
    config="cs",
    # Vgs=-0.7,
    ID=10 * 10**-3,
    Ffrom=10 * 10**6,
)

n.write_touchstone(
    "J310_CS_9V_ID10mA_nbgen",
    dir="/home/bev/Documents/Radio/QUCS-S/Studies/0010_S_Touchtone_lib",
)
# print(n.write_touchstone("n", dir="/tmp", return_string=True))
# Out:
# beta=2.013477 mS
# gm=8.974357 mS
