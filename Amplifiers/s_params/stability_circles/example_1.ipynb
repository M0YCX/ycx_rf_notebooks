# %% [markdown]
# # Stability Circles - book example
#
# > Ref: RF Circuit Design 2nd Edition by Chris Bowick [page 147]

# %%
import sys

# %matplotlib widget
from ycx_complex_numbers import S, Z

sys.path.append("../../../lib")
from nb_s_params import nb_calc_stability_circles

gain_db = 12
s11 = S().from_polar(0.4, 280)
s22 = S().from_polar(0.78, 345)
s12 = S().from_polar(0.048, 65)
s21 = S().from_polar(5.4, 103)

nb_calc_stability_circles(
    s11, s22, s12, s21, gain_db, title="Book Example 2N5179 @200MHz [page: 153]"
)
# Out:
# <hr><h2>Book Example 2N5179 @200MHz [page: 153]</h2><table><tr><th colspan="3" style="text-align:left;">S-Parameters:<tr><td>s11<td>S:0.06946-0.39392j : [mag:0.40000 ∠-80.00000] <td style="color: green; text-align: left;">$|s11| < 1$ center is stable</td><tr><td>s22<td>S:0.75342-0.20188j : [mag:0.78000 ∠-15.00000] <td style="color: green; text-align: left;">$|s22| < 1$ center is stable</td><tr><td>s12<td>S:0.02029+0.04350j : [mag:0.04800 ∠65.00000]<tr><td>s21<td>S:-1.21474+5.26160j : [mag:5.40000 ∠103.00000]<tr><td>$|s21|^2$<td>14.6 dB<tr><th colspan="3" style="text-align:left;"><tr><td>$D_S$<td>S:0.22634-0.36470j : [mag:0.42923 ∠-58.17532]</td><td style="text-align: left;">magnitude is $< 1$: True</td><tr><td>Rollett $K$<td style="color: red;">0.802<td style="text-align:left; color: red;">$(K \leq 1)$ NOT Unconditionally Stable<tr><th colspan="3" style="text-align:left;">Maximum Stable Gain:</th><tr><td>$MSG$<td>20.5 dB</td><tr><th colspan="3" style="text-align:left;">Stability Circ
# ...
